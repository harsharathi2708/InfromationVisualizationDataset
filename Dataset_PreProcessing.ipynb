# %%
import pandas as pd

# Replace with your raw GitHub URL
url = "https://gitlab.com/harsha.rathi/informationvisualizationdataset/-/raw/main/olympics.csv"

# Read the CSV file directly from the URL
df = pd.read_csv(url)

# Display the first few rows
print(df.head())
# Out:
#    id                      name sex   age  height  weight            team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    noc        games  year  season       city          sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               event medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
columns_to_fill = ['height', 'weight']

# Fill NA values with the mean of each specified column
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].mean())

# %%
df.head()
# Out:
#    id                      name sex   age     height     weight  \
# 0   1                 A Dijiang   M  24.0  180.00000  80.000000
# 1   2                  A Lamusi   M  23.0  170.00000  60.000000
# 2   3       Gunnar Nielsen Aaby   M  24.0  175.33897  70.702393
# 3   4      Edgar Lindenau Aabye   M  34.0  175.33897  70.702393
# 4   5  Christine Jacoba Aaftink   F  21.0  185.00000  82.000000
#
#              team  noc        games  year  season       city          sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               event medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df.to_csv('clean_olympics.csv', index=False)

# %%
import pandas as pd

# Load the dataset
url = "clean_olympics.csv"
data = pd.read_csv(url)

# Filter out only rows with medals
data_with_medals = data[data['medal'].notna()]
# Out:
#             id                                 name sex   age     height  \
# 3            4                 Edgar Lindenau Aabye   M  34.0  175.33897
# 37          15                 Arvo Ossian Aaltonen   M  30.0  175.33897
# 38          15                 Arvo Ossian Aaltonen   M  30.0  175.33897
# 40          16             Juhamatti Tapio Aaltonen   M  28.0  184.00000
# 41          17              Paavo Johannes Aaltonen   M  28.0  175.00000
# ...        ...                                  ...  ..   ...        ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0  168.00000
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0  168.00000
# 271082  135554                         Bogusaw Zych   M  28.0  182.00000
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0  171.00000
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0  171.00000
#
#            weight            team  noc        games  year  season       city  \
# 3       70.702393  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris
# 37      70.702393         Finland  FIN  1920 Summer  1920  Summer  Antwerpen
# 38      70.702393         Finland  FIN  1920 Summer  1920  Summer  Antwerpen
# 40      85.000000         Finland  FIN  2014 Winter  2014  Winter      Sochi
# 41      64.000000         Finland  FIN  1948 Summer  1948  Summer     London
# ...           ...             ...  ...          ...   ...     ...        ...
# 271078  80.000000    Soviet Union  URS  1956 Summer  1956  Summer  Melbourne
# 271080  80.000000    Soviet Union  URS  1964 Summer  1964  Summer      Tokyo
# 271082  82.000000          Poland  POL  1980 Summer  1980  Summer     Moskva
# 271102  64.000000          Russia  RUS  2000 Summer  2000  Summer     Sydney
# 271103  64.000000          Russia  RUS  2004 Summer  2004  Summer     Athina
#
#              sport                                   event   medal
# 3       Tug-Of-War             Tug-Of-War Men's Tug-Of-War    Gold
# 37        Swimming  Swimming Men's 200 metres Breaststroke  Bronze
# 38        Swimming  Swimming Men's 400 metres Breaststroke  Bronze
# 40      Ice Hockey             Ice Hockey Men's Ice Hockey  Bronze
# 41      Gymnastics  Gymnastics Men's Individual All-Around  Bronze
# ...            ...                                     ...     ...
# 271078   Athletics              Athletics Women's Shot Put  Silver
# 271080   Athletics              Athletics Women's Shot Put  Bronze
# 271082     Fencing                Fencing Men's Foil, Team  Bronze
# 271102   Athletics  Athletics Women's 4 x 400 metres Relay  Bronze
# 271103   Athletics  Athletics Women's 4 x 400 metres Relay  Silver
#
# [39783 rows x 15 columns]

# %%
# Group by country (NOC) and count medals
top_countries = (data_with_medals.groupby('noc')
                 .size()
                 .reset_index(name='MedalCount')
                 .sort_values(by='MedalCount', ascending=False)
                 .head(15))

# Filter the dataset to include only the top 15 countries
top15_data = data[data['noc'].isin(top_countries['noc'])]

# Save the filtered dataset to a CSV file
top15_data.to_csv("top15_countries.csv", index=False)

print("Filtered dataset saved as 'top15_countries.csv'.")
